# %%
import tensorflow as tf
from sklearn import preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import matplotlib.backends.backend_pdf
#import seaborn as sns
from os.path import join, os
from scipy import stats
from sklearn.svm import SVR, SVC
from sklearn.feature_selection import RFECV, SelectFromModel, SelectKBest, chi2, SelectPercentile
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
import time as tm
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score
import _pickle as cPickle
from scipy.stats import pearsonr

# %%
# RTDB 경로
RTDB_path = r'.\RTDB\RTDB.csv'
data_dir = r'.\analysis'

# %%
def DrawTimePlot(x,y, title):
    fig = plt.figure()
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    fig.autofmt_xdate()
    
    # Add axis labels
    plt.xlabel('time')
    plt.ylabel('2nd.bz.max.temp')
    plt.title(title)

    plt.plot(x,y)
    #fig.savefig(join(data_dir,title + '.pdf'))

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def getDataFrame(path):
    df = pd.read_csv(path, index_col=0)
    return df

# %%
def strtodate(date_arr):
    x = [dt.datetime.strptime(d,'%Y-%m-%d %H:%M') for d in date_arr]
    return x

# %%
def RemoveLowerOut(df,column_name):
    deout_df = df[(stats.zscore(df[column_name]) > -3)]
    return deout_df

# %%
if __name__ == "__main__":
    RTDB = getDataFrame(RTDB_path)
    RTDB = RTDB.drop(['Catalyst_V3_front_cl Content', 'Catalyst_V3_back_cl Content'],1)

    # What is the more userful?
    
    date = strtodate(RTDB.index)
    max_2nd_bz = RTDB['max_2nd.Burning.Zone']
    #max_2nd_bz = np.array(RTDB['max_2nd.Burning.Zone'])

# %%
RTDB = RemoveLowerOut(RTDB,'max_2nd.Burning.Zone')

date = strtodate(RTDB.index)
max_2nd_bz = RTDB['max_2nd.Burning.Zone']

#DrawTimePlot(date,max_2nd_bz, 'Remove outlier max temp plot')

# %%
idx_RTDB = RTDB.reset_index() # Remove NaN row


x_RTDB = idx_RTDB.drop(['max_2nd.Burning.Zone', 'max_2nd.1dan', 'max_2nd.2dan', 
                         'max_2nd.3dan', 'max_2nd.4dan', 'max_2nd.5dan', 'index'],1)
idx_RTDB = idx_RTDB.drop(['max_2nd.1dan', 'max_2nd.2dan', 
                         'max_2nd.3dan', 'max_2nd.4dan', 'max_2nd.5dan', 'index'],1)

x_RTDB = x_RTDB[:len(x_RTDB)-120]
idx_RTDB = idx_RTDB[:len(idx_RTDB)-120]

train_x = x_RTDB.loc[1:(len(idx_RTDB)*4/5)]
train_y = idx_RTDB.loc[1:(len(idx_RTDB)*4/5),['max_2nd.Burning.Zone']]

test_x = x_RTDB.loc[(len(idx_RTDB)*4/5):]
test_y = idx_RTDB.loc[(len(idx_RTDB)*4/5):, ['max_2nd.Burning.Zone']]

short_x = x_RTDB.loc[1:(len(idx_RTDB)*1/5)]
short_y = idx_RTDB.loc[1:(len(idx_RTDB)*1/5),['max_2nd.Burning.Zone']]

short_x_t = x_RTDB.loc[(len(idx_RTDB)*1/5):(len(idx_RTDB)*6/25)]
short_y_t = idx_RTDB.loc[(len(idx_RTDB)*1/5):(len(idx_RTDB)*6/25),['max_2nd.Burning.Zone']]

dnn_train_x = idx_RTDB.loc[:(len(idx_RTDB)*4/5)]
dnn_train_x.columns = [col.replace(' ', '_') for col in dnn_train_x.columns]
dnn_train_y = idx_RTDB.loc[(len(idx_RTDB)*4/5):]
dnn_train_y.columns = [col.replace(' ', '_') for col in dnn_train_x.columns]

train_y_label = pd.DataFrame(train_y['max_2nd.Burning.Zone'].apply(lambda x: 1 if x >=550 else 0))
test_y_label = pd.DataFrame(test_y['max_2nd.Burning.Zone'].apply(lambda x: 1 if x >=550 else 0))
short_y_label = pd.DataFrame(short_y['max_2nd.Burning.Zone'].apply(lambda x: 1 if x >=550 else 0))

# %%
scaler = preprocessing.StandardScaler().fit(train_x)
scale_train = scaler.transform(train_x) 
scale_test = scaler.transform(test_x)

scaled_train_df = pd.DataFrame(
    scale_train, index=train_x.index, columns=train_x.columns)

scaled_test_df = pd.DataFrame(
    scale_test, index=test_x.index, columns=test_x.columns)

# %%
feature = [
    'R1_RDT_Total_Feed',
    'R1_RDT_T_PAR',
    'R2_RDT_Total_Feed',
    'R3_RDT_Total_Feed',
    'R4_RDT_T_ARO',
    'Re_Gas_H2_purity',
    'C_1_DISCH',
    'C_1_SUCTION',
    'V-3 1ST BURN ZON E-1 INLET GAS',
    'V-3 1ST BURN ZON H-1 OUTLET',
    'R3_RDT_T_ARO',
    'R4_RDT_Total_Feed',
    'R1_New_Wait',
    'R2_New_Wait',
    'R3_New_Wait',
    'R4_New_Wait',
    'Burning Gas C-2 OUT TO V-3',
    'R3_RDT_PAR_FEED',
    'R3_RDT_T_PAR',
    'R4_RDT_T_PAR',
    'R4_RDT_PAR_FEED',
    'R2_RIT_mean',
    'R2_RIT_max',
    
    
]

scaled_train_df = scaled_train_df[feature]
scaled_test_df = scaled_test_df[feature]

# %%
start_time = tm.time()
svr = SVR('rbf', verbose=True)

svr.fit(scaled_train_df, train_y['max_2nd.Burning.Zone'])
print("svr classification termination %s seconds ---" % (tm.time() - start_time))
# Out:
# [LibSVM]svr classification termination 1296.9477803707123 seconds ---

# %%
prediction = svr.predict(scaled_test_df)
real = test_y['max_2nd.Burning.Zone']
score = svr.score(scaled_test_df, real)
print(prediction)
print(score)
RMSE = mean_squared_error(real, prediction)**0.5
print(RMSE)
# Out:
# [ 542.62181973  543.02529388  542.47466391 ...,  542.16881802  542.12708066
#   542.12074808]
# 0.221821552477
# 4.06858241274

# %%
r2_score(real, prediction)
# Out:
# -0.49266001846695029

# %%
print("MAPE : %.2f%%" %round(mean_absolute_percentage_error(real, prediction),2))
# Out:
# MAPE : 0.56%

# %%
pearsonr(real,prediction)
# Out:
# (0.58062800672278236, 0.0)

# %%
date_arr = RTDB.reset_index()[:len(RTDB)-120]
test_date = np.array(date_arr.loc[(len(date_arr)*4/5):,'index'])

# %%
strtodate(test_date)
# Out:
# [datetime.datetime(2017, 4, 14, 8, 6),
#  datetime.datetime(2017, 4, 14, 8, 7),
#  datetime.datetime(2017, 4, 14, 8, 8),
#  datetime.datetime(2017, 4, 14, 8, 9),
#  datetime.datetime(2017, 4, 14, 8, 10),
#  datetime.datetime(2017, 4, 14, 8, 11),
#  datetime.datetime(2017, 4, 14, 8, 12),
#  datetime.datetime(2017, 4, 14, 8, 13),
#  datetime.datetime(2017, 4, 14, 8, 14),
#  datetime.datetime(2017, 4, 14, 8, 15),
#  datetime.datetime(2017, 4, 14, 8, 16),
#  datetime.datetime(2017, 4, 14, 8, 17),
#  datetime.datetime(2017, 4, 14, 8, 18),
#  datetime.datetime(2017, 4, 14, 8, 19),
#  datetime.datetime(2017, 4, 14, 8, 20),
#  datetime.datetime(2017, 4, 14, 8, 21),
#  datetime.datetime(2017, 4, 14, 8, 22),
#  datetime.datetime(2017, 4, 14, 8, 23),
#  datetime.datetime(2017, 4, 14, 8, 24),
#  datetime.datetime(2017, 4, 14, 8, 25),
#  datetime.datetime(2017, 4, 14, 8, 26),
#  datetime.datetime(2017, 4, 14, 8, 27),
#  datetime.datetime(2017, 4, 14, 8, 28),
#  datetime.datetime(2017, 4, 14, 8, 29),
#  datetime.datetime(2017, 4, 14, 8, 30),
#  datetime.datetime(2017, 4, 14, 8, 31),
#  datetime.datetime(2017, 4, 14, 8, 32),
#  datetime.datetime(2017, 4, 14, 8, 33),
#  datetime.datetime(2017, 4, 14, 8, 34),
#  datetime.datetime(2017, 4, 14, 8, 35),
#  datetime.datetime(2017, 4, 14, 8, 36),
#  datetime.datetime(2017, 4, 14, 8, 37),
#  datetime.datetime(2017, 4, 14, 8, 38),
#  datetime.datetime(2017, 4, 14, 8, 39),
#  datetime.datetime(2017, 4, 14, 8, 40),
#  datetime.datetime(2017, 4, 14, 8, 41),
#  datetime.datetime(2017, 4, 14, 8, 42),
#  datetime.datetime(2017, 4, 14, 8, 43),
#  datetime.datetime(2017, 4, 14, 8, 44),
#  datetime.datetime(2017, 4, 14, 8, 45),
#  datetime.datetime(2017, 4, 14, 8, 46),
#  datetime.datetime(2017, 4, 14, 8, 47),
#  datetime.datetime(2017, 4, 14, 8, 48),
#  datetime.datetime(2017, 4, 14, 8, 49),
#  datetime.datetime(2017, 4, 14, 8, 50),
#  datetime.datetime(2017, 4, 14, 8, 51),
#  datetime.datetime(2017, 4, 14, 8, 52),
#  datetime.datetime(2017, 4, 14, 8, 53),
#  datetime.datetime(2017, 4, 14, 8, 54),
#  datetime.datetime(2017, 4, 14, 8, 55),
#  datetime.datetime(2017, 4, 14, 8, 56),
#  datetime.datetime(2017, 4, 14, 8, 57),
#  datetime.datetime(2017, 4, 14, 8, 58),
#  datetime.datetime(2017, 4, 14, 8, 59),
#  datetime.datetime(2017, 4, 14, 9, 0),
#  datetime.datetime(2017, 4, 14, 9, 1),
#  datetime.datetime(2017, 4, 14, 9, 2),
#  datetime.datetime(2017, 4, 14, 9, 3),
#  datetime.datetime(2017, 4, 14, 9, 4),
#  datetime.datetime(2017, 4, 14, 9, 5),
#  datetime.datetime(2017, 4, 14, 9, 6),
#  datetime.datetime(2017, 4, 14, 9, 7),
#  datetime.datetime(2017, 4, 14, 9, 8),
#  datetime.datetime(2017, 4, 14, 9, 9),
#  datetime.datetime(2017, 4, 14, 9, 10),
#  datetime.datetime(2017, 4, 14, 9, 11),
#  datetime.datetime(2017, 4, 14, 9, 12),
#  datetime.datetime(2017, 4, 14, 9, 13),
#  datetime.datetime(2017, 4, 14, 9, 14),
#  datetime.datetime(2017, 4, 14, 9, 15),
#  datetime.datetime(2017, 4, 14, 9, 16),
#  datetime.datetime(2017, 4, 14, 9, 17),
#  datetime.datetime(2017, 4, 14, 9, 18),
#  datetime.datetime(2017, 4, 14, 9, 19),
#  datetime.datetime(2017, 4, 14, 9, 20),
#  datetime.datetime(2017, 4, 14, 9, 21),
#  datetime.datetime(2017, 4, 14, 9, 22),
#  datetime.datetime(2017, 4, 14, 9, 23),
#  datetime.datetime(2017, 4, 14, 9, 24),
#  datetime.datetime(2017, 4, 14, 9, 25),
#  datetime.datetime(2017, 4, 14, 9, 26),
#  datetime.datetime(2017, 4, 14, 9, 27),
#  datetime.datetime(2017, 4, 14, 9, 28),
#  datetime.datetime(2017, 4, 14, 9, 29),
#  datetime.datetime(2017, 4, 14, 9, 30),
#  datetime.datetime(2017, 4, 14, 9, 31),
#  datetime.datetime(2017, 4, 14, 9, 32),
#  datetime.datetime(2017, 4, 14, 9, 33),
#  datetime.datetime(2017, 4, 14, 9, 34),
#  datetime.datetime(2017, 4, 14, 9, 35),
#  datetime.datetime(2017, 4, 14, 9, 36),
#  datetime.datetime(2017, 4, 14, 9, 37),
#  datetime.datetime(2017, 4, 14, 9, 38),
#  datetime.datetime(2017, 4, 14, 9, 39),
#  datetime.datetime(2017, 4, 14, 9, 40),
#  datetime.datetime(2017, 4, 14, 9, 41),
#  datetime.datetime(2017, 4, 14, 9, 42),
#  datetime.datetime(2017, 4, 14, 9, 43),
#  datetime.datetime(2017, 4, 14, 9, 44),
#  datetime.datetime(2017, 4, 14, 9, 45),
#  datetime.datetime(2017, 4, 14, 9, 46),
#  datetime.datetime(2017, 4, 14, 9, 47),
#  datetime.datetime(2017, 4, 14, 9, 48),
#  datetime.datetime(2017, 4, 14, 9, 49),
#  datetime.datetime(2017, 4, 14, 9, 50),
#  datetime.datetime(2017, 4, 14, 9, 51),
#  datetime.datetime(2017, 4, 14, 9, 52),
#  datetime.datetime(2017, 4, 14, 9, 53),
#  datetime.datetime(2017, 4, 14, 9, 54),
#  datetime.datetime(2017, 4, 14, 9, 55),
#  datetime.datetime(2017, 4, 14, 9, 56),
#  datetime.datetime(2017, 4, 14, 9, 57),
#  datetime.datetime(2017, 4, 14, 9, 58),
#  datetime.datetime(2017, 4, 14, 9, 59),
#  datetime.datetime(2017, 4, 14, 10, 0),
#  datetime.datetime(2017, 4, 14, 10, 1),
#  datetime.datetime(2017, 4, 14, 10, 2),
#  datetime.datetime(2017, 4, 14, 10, 3),
#  datetime.datetime(2017, 4, 14, 10, 4),
#  datetime.datetime(2017, 4, 14, 10, 5),
#  datetime.datetime(2017, 4, 14, 10, 6),
#  datetime.datetime(2017, 4, 14, 10, 7),
#  datetime.datetime(2017, 4, 14, 10, 8),
#  datetime.datetime(2017, 4, 14, 10, 9),
#  datetime.datetime(2017, 4, 14, 10, 10),
#  datetime.datetime(2017, 4, 14, 10, 11),
#  datetime.datetime(2017, 4, 14, 10, 12),
#  datetime.datetime(2017, 4, 14, 10, 13),
#  datetime.datetime(2017, 4, 14, 10, 14),
#  datetime.datetime(2017, 4, 14, 10, 15),
#  datetime.datetime(2017, 4, 14, 10, 16),
#  datetime.datetime(2017, 4, 14, 10, 17),
#  datetime.datetime(2017, 4, 14, 10, 18),
#  datetime.datetime(2017, 4, 14, 10, 19),
#  datetime.datetime(2017, 4, 14, 10, 20),
#  datetime.datetime(2017, 4, 14, 10, 21),
#  datetime.datetime(2017, 4, 14, 10, 22),
#  datetime.datetime(2017, 4, 14, 10, 23),
#  datetime.datetime(2017, 4, 14, 10, 24),
#  datetime.datetime(2017, 4, 14, 10, 25),
#  datetime.datetime(2017, 4, 14, 10, 26),
#  datetime.datetime(2017, 4, 14, 10, 27),
#  datetime.datetime(2017, 4, 14, 10, 28),
#  datetime.datetime(2017, 4, 14, 10, 29),
#  datetime.datetime(2017, 4, 14, 10, 30),
#  datetime.datetime(2017, 4, 14, 10, 31),
#  datetime.datetime(2017, 4, 14, 10, 32),
#  datetime.datetime(2017, 4, 14, 10, 33),
#  datetime.datetime(2017, 4, 14, 10, 34),
#  datetime.datetime(2017, 4, 14, 10, 35),
#  datetime.datetime(2017, 4, 14, 10, 36),
#  datetime.datetime(2017, 4, 14, 10, 37),
#  datetime.datetime(2017, 4, 14, 10, 38),
#  datetime.datetime(2017, 4, 14, 10, 39),
#  datetime.datetime(2017, 4, 14, 10, 40),
#  datetime.datetime(2017, 4, 14, 10, 41),
#  datetime.datetime(2017, 4, 14, 10, 42),
#  datetime.datetime(2017, 4, 14, 10, 43),
#  datetime.datetime(2017, 4, 14, 10, 44),
#  datetime.datetime(2017, 4, 14, 10, 45),
#  datetime.datetime(2017, 4, 14, 10, 46),
#  datetime.datetime(2017, 4, 14, 10, 47),
#  datetime.datetime(2017, 4, 14, 10, 48),
#  datetime.datetime(2017, 4, 14, 10, 49),
#  datetime.datetime(2017, 4, 14, 10, 50),
#  datetime.datetime(2017, 4, 14, 10, 51),
#  datetime.datetime(2017, 4, 14, 10, 52),
#  datetime.datetime(2017, 4, 14, 10, 53),
#  datetime.datetime(2017, 4, 14, 10, 54),
#  datetime.datetime(2017, 4, 14, 10, 55),
#  datetime.datetime(2017, 4, 14, 10, 56),
#  datetime.datetime(2017, 4, 14, 10, 57),
#  datetime.datetime(2017, 4, 14, 10, 58),
#  datetime.datetime(2017, 4, 14, 10, 59),
#  datetime.datetime(2017, 4, 14, 11, 0),
#  datetime.datetime(2017, 4, 14, 11, 1),
#  datetime.datetime(2017, 4, 14, 11, 2),
#  datetime.datetime(2017, 4, 14, 11, 3),
#  datetime.datetime(2017, 4, 14, 11, 4),
#  datetime.datetime(2017, 4, 14, 11, 5),
#  datetime.datetime(2017, 4, 14, 11, 6),
#  datetime.datetime(2017, 4, 14, 11, 7),
#  datetime.datetime(2017, 4, 14, 11, 8),
#  datetime.datetime(2017, 4, 14, 11, 9),
#  datetime.datetime(2017, 4, 14, 11, 10),
#  datetime.datetime(2017, 4, 14, 11, 11),
#  datetime.datetime(2017, 4, 14, 11, 12),
#  datetime.datetime(2017, 4, 14, 11, 13),
#  datetime.datetime(2017, 4, 14, 11, 14),
#  datetime.datetime(2017, 4, 14, 11, 15),
#  datetime.datetime(2017, 4, 14, 11, 16),
#  datetime.datetime(2017, 4, 14, 11, 17),
#  datetime.datetime(2017, 4, 14, 11, 18),
#  datetime.datetime(2017, 4, 14, 11, 19),
#  datetime.datetime(2017, 4, 14, 11, 20),
#  datetime.datetime(2017, 4, 14, 11, 21),
#  datetime.datetime(2017, 4, 14, 11, 22),
#  datetime.datetime(2017, 4, 14, 11, 23),
#  datetime.datetime(2017, 4, 14, 11, 24),
#  datetime.datetime(2017, 4, 14, 11, 25),
#  datetime.datetime(2017, 4, 14, 11, 26),
#  datetime.datetime(2017, 4, 14, 11, 27),
#  datetime.datetime(2017, 4, 14, 11, 28),
#  datetime.datetime(2017, 4, 14, 11, 29),
#  datetime.datetime(2017, 4, 14, 11, 30),
#  datetime.datetime(2017, 4, 14, 11, 31),
#  datetime.datetime(2017, 4, 14, 11, 32),
#  datetime.datetime(2017, 4, 14, 11, 33),
#  datetime.datetime(2017, 4, 14, 11, 34),
#  datetime.datetime(2017, 4, 14, 11, 35),
#  datetime.datetime(2017, 4, 14, 11, 36),
#  datetime.datetime(2017, 4, 14, 11, 37),
#  datetime.datetime(2017, 4, 14, 11, 38),
#  datetime.datetime(2017, 4, 14, 11, 39),
#  datetime.datetime(2017, 4, 14, 11, 40),
#  datetime.datetime(2017, 4, 14, 11, 41),
#  datetime.datetime(2017, 4, 14, 11, 42),
#  datetime.datetime(2017, 4, 14, 11, 43),
#  datetime.datetime(2017, 4, 14, 11, 44),
#  datetime.datetime(2017, 4, 14, 11, 45),
#  datetime.datetime(2017, 4, 14, 11, 46),
#  datetime.datetime(2017, 4, 14, 11, 47),
#  datetime.datetime(2017, 4, 14, 11, 48),
#  datetime.datetime(2017, 4, 14, 11, 49),
#  datetime.datetime(2017, 4, 14, 11, 50),
#  datetime.datetime(2017, 4, 14, 11, 51),
#  datetime.datetime(2017, 4, 14, 11, 52),
#  datetime.datetime(2017, 4, 14, 11, 53),
#  datetime.datetime(2017, 4, 14, 11, 54),
#  datetime.datetime(2017, 4, 14, 11, 55),
#  datetime.datetime(2017, 4, 14, 11, 56),
#  datetime.datetime(2017, 4, 14, 11, 57),
#  datetime.datetime(2017, 4, 14, 11, 58),
#  datetime.datetime(2017, 4, 14, 11, 59),
#  datetime.datetime(2017, 4, 14, 12, 0),
#  datetime.datetime(2017, 4, 14, 12, 1),
#  datetime.datetime(2017, 4, 14, 12, 2),
#  datetime.datetime(2017, 4, 14, 12, 3),
#  datetime.datetime(2017, 4, 14, 12, 4),
#  datetime.datetime(2017, 4, 14, 12, 5),
#  datetime.datetime(2017, 4, 14, 12, 6),
#  datetime.datetime(2017, 4, 14, 12, 7),
#  datetime.datetime(2017, 4, 14, 12, 8),
#  datetime.datetime(2017, 4, 14, 12, 9),
#  datetime.datetime(2017, 4, 14, 12, 10),
#  datetime.datetime(2017, 4, 14, 12, 11),
#  datetime.datetime(2017, 4, 14, 12, 12),
#  datetime.datetime(2017, 4, 14, 12, 13),
#  datetime.datetime(2017, 4, 14, 12, 14),
#  datetime.datetime(2017, 4, 14, 12, 15),
#  datetime.datetime(2017, 4, 14, 12, 16),
#  datetime.datetime(2017, 4, 14, 12, 17),
#  datetime.datetime(2017, 4, 14, 12, 18),
#  datetime.datetime(2017, 4, 14, 12, 19),
#  datetime.datetime(2017, 4, 14, 12, 20),
#  datetime.datetime(2017, 4, 14, 12, 21),
#  datetime.datetime(2017, 4, 14, 12, 22),
#  datetime.datetime(2017, 4, 14, 12, 23),
#  datetime.datetime(2017, 4, 14, 12, 24),
#  datetime.datetime(2017, 4, 14, 12, 25),
#  datetime.datetime(2017, 4, 14, 12, 26),
#  datetime.datetime(2017, 4, 14, 12, 27),
#  datetime.datetime(2017, 4, 14, 12, 28),
#  datetime.datetime(2017, 4, 14, 12, 29),
#  datetime.datetime(2017, 4, 14, 12, 30),
#  datetime.datetime(2017, 4, 14, 12, 31),
#  datetime.datetime(2017, 4, 14, 12, 32),
#  datetime.datetime(2017, 4, 14, 12, 33),
#  datetime.datetime(2017, 4, 14, 12, 34),
#  datetime.datetime(2017, 4, 14, 12, 35),
#  datetime.datetime(2017, 4, 14, 12, 36),
#  datetime.datetime(2017, 4, 14, 12, 37),
#  datetime.datetime(2017, 4, 14, 12, 38),
#  datetime.datetime(2017, 4, 14, 12, 39),
#  datetime.datetime(2017, 4, 14, 12, 40),
#  datetime.datetime(2017, 4, 14, 12, 41),
#  datetime.datetime(2017, 4, 14, 12, 42),
#  datetime.datetime(2017, 4, 14, 12, 43),
#  datetime.datetime(2017, 4, 14, 12, 44),
#  datetime.datetime(2017, 4, 14, 12, 45),
#  datetime.datetime(2017, 4, 14, 12, 46),
#  datetime.datetime(2017, 4, 14, 12, 47),
#  datetime.datetime(2017, 4, 14, 12, 48),
#  datetime.datetime(2017, 4, 14, 12, 49),
#  datetime.datetime(2017, 4, 14, 12, 50),
#  datetime.datetime(2017, 4, 14, 12, 51),
#  datetime.datetime(2017, 4, 14, 12, 52),
#  datetime.datetime(2017, 4, 14, 12, 53),
#  datetime.datetime(2017, 4, 14, 12, 54),
#  datetime.datetime(2017, 4, 14, 12, 55),
#  datetime.datetime(2017, 4, 14, 12, 56),
#  datetime.datetime(2017, 4, 14, 12, 57),
#  datetime.datetime(2017, 4, 14, 12, 58),
#  datetime.datetime(2017, 4, 14, 12, 59),
#  datetime.datetime(2017, 4, 14, 13, 0),
#  datetime.datetime(2017, 4, 14, 13, 1),
#  datetime.datetime(2017, 4, 14, 13, 2),
#  datetime.datetime(2017, 4, 14, 13, 3),
#  datetime.datetime(2017, 4, 14, 13, 4),
#  datetime.datetime(2017, 4, 14, 13, 5),
#  datetime.datetime(2017, 4, 14, 13, 6),
#  datetime.datetime(2017, 4, 14, 13, 7),
#  datetime.datetime(2017, 4, 14, 13, 8),
#  datetime.datetime(2017, 4, 14, 13, 9),
#  datetime.datetime(2017, 4, 14, 13, 10),
#  datetime.datetime(2017, 4, 14, 13, 11),
#  datetime.datetime(2017, 4, 14, 13, 12),
#  datetime.datetime(2017, 4, 14, 13, 13),
#  datetime.datetime(2017, 4, 14, 13, 14),
#  datetime.datetime(2017, 4, 14, 13, 15),
#  datetime.datetime(2017, 4, 14, 13, 16),
#  datetime.datetime(2017, 4, 14, 13, 17),
#  datetime.datetime(2017, 4, 14, 13, 18),
#  datetime.datetime(2017, 4, 14, 13, 19),
#  datetime.datetime(2017, 4, 14, 13, 20),
#  datetime.datetime(2017, 4, 14, 13, 21),
#  datetime.datetime(2017, 4, 14, 13, 22),
#  datetime.datetime(2017, 4, 14, 13, 23),
#  datetime.datetime(2017, 4, 14, 13, 24),
#  datetime.datetime(2017, 4, 14, 13, 25),
#  datetime.datetime(2017, 4, 14, 13, 26),
#  datetime.datetime(2017, 4, 14, 13, 27),
#  datetime.datetime(2017, 4, 14, 13, 28),
#  datetime.datetime(2017, 4, 14, 13, 29),
#  datetime.datetime(2017, 4, 14, 13, 30),
#  datetime.datetime(2017, 4, 14, 13, 31),
#  datetime.datetime(2017, 4, 14, 13, 32),
#  datetime.datetime(2017, 4, 14, 13, 33),
#  datetime.datetime(2017, 4, 14, 13, 34),
#  datetime.datetime(2017, 4, 14, 13, 35),
#  datetime.datetime(2017, 4, 14, 13, 36),
#  datetime.datetime(2017, 4, 14, 13, 37),
#  datetime.datetime(2017, 4, 14, 13, 38),
#  datetime.datetime(2017, 4, 14, 13, 39),
#  datetime.datetime(2017, 4, 14, 13, 40),
#  datetime.datetime(2017, 4, 14, 13, 41),
#  datetime.datetime(2017, 4, 14, 13, 42),
#  datetime.datetime(2017, 4, 14, 13, 43),
#  datetime.datetime(2017, 4, 14, 13, 44),
#  datetime.datetime(2017, 4, 14, 13, 45),
#  datetime.datetime(2017, 4, 14, 13, 46),
#  datetime.datetime(2017, 4, 14, 13, 47),
#  datetime.datetime(2017, 4, 14, 13, 48),
#  datetime.datetime(2017, 4, 14, 13, 49),
#  datetime.datetime(2017, 4, 14, 13, 50),
#  datetime.datetime(2017, 4, 14, 13, 51),
#  datetime.datetime(2017, 4, 14, 13, 52),
#  datetime.datetime(2017, 4, 14, 13, 53),
#  datetime.datetime(2017, 4, 14, 13, 54),
#  datetime.datetime(2017, 4, 14, 13, 55),
#  datetime.datetime(2017, 4, 14, 13, 56),
#  datetime.datetime(2017, 4, 14, 13, 57),
#  datetime.datetime(2017, 4, 14, 13, 58),
#  datetime.datetime(2017, 4, 14, 13, 59),
#  datetime.datetime(2017, 4, 14, 14, 0),
#  datetime.datetime(2017, 4, 14, 14, 1),
#  datetime.datetime(2017, 4, 14, 14, 2),
#  datetime.datetime(2017, 4, 14, 14, 3),
#  datetime.datetime(2017, 4, 14, 14, 4),
#  datetime.datetime(2017, 4, 14, 14, 5),
#  datetime.datetime(2017, 4, 14, 14, 6),
#  datetime.datetime(2017, 4, 14, 14, 7),
#  datetime.datetime(2017, 4, 14, 14, 8),
#  datetime.datetime(2017, 4, 14, 14, 9),
#  datetime.datetime(2017, 4, 14, 14, 10),
#  datetime.datetime(2017, 4, 14, 14, 11),
#  datetime.datetime(2017, 4, 14, 14, 12),
#  datetime.datetime(2017, 4, 14, 14, 13),
#  datetime.datetime(2017, 4, 14, 14, 14),
#  datetime.datetime(2017, 4, 14, 14, 15),
#  datetime.datetime(2017, 4, 14, 14, 16),
#  datetime.datetime(2017, 4, 14, 14, 17),
#  datetime.datetime(2017, 4, 14, 14, 18),
#  datetime.datetime(2017, 4, 14, 14, 19),
#  datetime.datetime(2017, 4, 14, 14, 20),
#  datetime.datetime(2017, 4, 14, 14, 21),
#  datetime.datetime(2017, 4, 14, 14, 22),
#  datetime.datetime(2017, 4, 14, 14, 23),
#  datetime.datetime(2017, 4, 14, 14, 24),
#  datetime.datetime(2017, 4, 14, 14, 25),
#  datetime.datetime(2017, 4, 14, 14, 26),
#  datetime.datetime(2017, 4, 14, 14, 27),
#  datetime.datetime(2017, 4, 14, 14, 28),
#  datetime.datetime(2017, 4, 14, 14, 29),
#  datetime.datetime(2017, 4, 14, 14, 30),
#  datetime.datetime(2017, 4, 14, 14, 31),
#  datetime.datetime(2017, 4, 14, 14, 32),
#  datetime.datetime(2017, 4, 14, 14, 33),
#  datetime.datetime(2017, 4, 14, 14, 34),
#  datetime.datetime(2017, 4, 14, 14, 35),
#  datetime.datetime(2017, 4, 14, 14, 36),
#  datetime.datetime(2017, 4, 14, 14, 37),
#  datetime.datetime(2017, 4, 14, 14, 38),
#  datetime.datetime(2017, 4, 14, 14, 39),
#  datetime.datetime(2017, 4, 14, 14, 40),
#  datetime.datetime(2017, 4, 14, 14, 41),
#  datetime.datetime(2017, 4, 14, 14, 42),
#  datetime.datetime(2017, 4, 14, 14, 43),
#  datetime.datetime(2017, 4, 14, 14, 44),
#  datetime.datetime(2017, 4, 14, 14, 45),
#  datetime.datetime(2017, 4, 14, 14, 46),
#  datetime.datetime(2017, 4, 14, 14, 47),
#  datetime.datetime(2017, 4, 14, 14, 48),
#  datetime.datetime(2017, 4, 14, 14, 49),
#  datetime.datetime(2017, 4, 14, 14, 50),
#  datetime.datetime(2017, 4, 14, 14, 51),
#  datetime.datetime(2017, 4, 14, 14, 52),
#  datetime.datetime(2017, 4, 14, 14, 53),
#  datetime.datetime(2017, 4, 14, 14, 54),
#  datetime.datetime(2017, 4, 14, 14, 55),
#  datetime.datetime(2017, 4, 14, 14, 56),
#  datetime.datetime(2017, 4, 14, 14, 57),
#  datetime.datetime(2017, 4, 14, 14, 58),
#  datetime.datetime(2017, 4, 14, 14, 59),
#  datetime.datetime(2017, 4, 14, 15, 0),
#  datetime.datetime(2017, 4, 14, 15, 1),
#  datetime.datetime(2017, 4, 14, 15, 2),
#  datetime.datetime(2017, 4, 14, 15, 3),
#  datetime.datetime(2017, 4, 14, 15, 4),
#  datetime.datetime(2017, 4, 14, 15, 5),
#  datetime.datetime(2017, 4, 14, 15, 6),
#  datetime.datetime(2017, 4, 14, 15, 7),
#  datetime.datetime(2017, 4, 14, 15, 8),
#  datetime.datetime(2017, 4, 14, 15, 9),
#  datetime.datetime(2017, 4, 14, 15, 10),
#  datetime.datetime(2017, 4, 14, 15, 11),
#  datetime.datetime(2017, 4, 14, 15, 12),
#  datetime.datetime(2017, 4, 14, 15, 13),
#  datetime.datetime(2017, 4, 14, 15, 14),
#  datetime.datetime(2017, 4, 14, 15, 15),
#  datetime.datetime(2017, 4, 14, 15, 16),
#  datetime.datetime(2017, 4, 14, 15, 17),
#  datetime.datetime(2017, 4, 14, 15, 18),
#  datetime.datetime(2017, 4, 14, 15, 19),
#  datetime.datetime(2017, 4, 14, 15, 20),
#  datetime.datetime(2017, 4, 14, 15, 21),
#  datetime.datetime(2017, 4, 14, 15, 22),
#  datetime.datetime(2017, 4, 14, 15, 23),
#  datetime.datetime(2017, 4, 14, 15, 24),
#  datetime.datetime(2017, 4, 14, 15, 25),
#  datetime.datetime(2017, 4, 14, 15, 26),
#  datetime.datetime(2017, 4, 14, 15, 27),
#  datetime.datetime(2017, 4, 14, 15, 28),
#  datetime.datetime(2017, 4, 14, 15, 29),
#  datetime.datetime(2017, 4, 14, 15, 30),
#  datetime.datetime(2017, 4, 14, 15, 31),
#  datetime.datetime(2017, 4, 14, 15, 32),
#  datetime.datetime(2017, 4, 14, 15, 33),
#  datetime.datetime(2017, 4, 14, 15, 34),
#  datetime.datetime(2017, 4, 14, 15, 35),
#  datetime.datetime(2017, 4, 14, 15, 36),
#  datetime.datetime(2017, 4, 14, 15, 37),
#  datetime.datetime(2017, 4, 14, 15, 38),
#  datetime.datetime(2017, 4, 14, 15, 39),
#  datetime.datetime(2017, 4, 14, 15, 40),
#  datetime.datetime(2017, 4, 14, 15, 41),
#  datetime.datetime(2017, 4, 14, 15, 42),
#  datetime.datetime(2017, 4, 14, 15, 43),
#  datetime.datetime(2017, 4, 14, 15, 44),
#  datetime.datetime(2017, 4, 14, 15, 45),
#  datetime.datetime(2017, 4, 14, 15, 46),
#  datetime.datetime(2017, 4, 14, 15, 47),
#  datetime.datetime(2017, 4, 14, 15, 48),
#  datetime.datetime(2017, 4, 14, 15, 49),
#  datetime.datetime(2017, 4, 14, 15, 50),
#  datetime.datetime(2017, 4, 14, 15, 51),
#  datetime.datetime(2017, 4, 14, 15, 52),
#  datetime.datetime(2017, 4, 14, 15, 53),
#  datetime.datetime(2017, 4, 14, 15, 54),
#  datetime.datetime(2017, 4, 14, 15, 55),
#  datetime.datetime(2017, 4, 14, 15, 56),
#  datetime.datetime(2017, 4, 14, 15, 57),
#  datetime.datetime(2017, 4, 14, 15, 58),
#  datetime.datetime(2017, 4, 14, 15, 59),
#  datetime.datetime(2017, 4, 14, 16, 0),
#  datetime.datetime(2017, 4, 14, 16, 1),
#  datetime.datetime(2017, 4, 14, 16, 2),
#  datetime.datetime(2017, 4, 14, 16, 3),
#  datetime.datetime(2017, 4, 14, 16, 4),
#  datetime.datetime(2017, 4, 14, 16, 5),
#  datetime.datetime(2017, 4, 14, 16, 6),
#  datetime.datetime(2017, 4, 14, 16, 7),
#  datetime.datetime(2017, 4, 14, 16, 8),
#  datetime.datetime(2017, 4, 14, 16, 9),
#  datetime.datetime(2017, 4, 14, 16, 10),
#  datetime.datetime(2017, 4, 14, 16, 11),
#  datetime.datetime(2017, 4, 14, 16, 12),
#  datetime.datetime(2017, 4, 14, 16, 13),
#  datetime.datetime(2017, 4, 14, 16, 14),
#  datetime.datetime(2017, 4, 14, 16, 15),
#  datetime.datetime(2017, 4, 14, 16, 16),
#  datetime.datetime(2017, 4, 14, 16, 17),
#  datetime.datetime(2017, 4, 14, 16, 18),
#  datetime.datetime(2017, 4, 14, 16, 19),
#  datetime.datetime(2017, 4, 14, 16, 20),
#  datetime.datetime(2017, 4, 14, 16, 21),
#  datetime.datetime(2017, 4, 14, 16, 22),
#  datetime.datetime(2017, 4, 14, 16, 23),
#  datetime.datetime(2017, 4, 14, 16, 24),
#  datetime.datetime(2017, 4, 14, 16, 25),
#  datetime.datetime(2017, 4, 14, 16, 26),
#  datetime.datetime(2017, 4, 14, 16, 27),
#  datetime.datetime(2017, 4, 14, 16, 28),
#  datetime.datetime(2017, 4, 14, 16, 29),
#  datetime.datetime(2017, 4, 14, 16, 30),
#  datetime.datetime(2017, 4, 14, 16, 31),
#  datetime.datetime(2017, 4, 14, 16, 32),
#  datetime.datetime(2017, 4, 14, 16, 33),
#  datetime.datetime(2017, 4, 14, 16, 34),
#  datetime.datetime(2017, 4, 14, 16, 35),
#  datetime.datetime(2017, 4, 14, 16, 36),
#  datetime.datetime(2017, 4, 14, 16, 37),
#  datetime.datetime(2017, 4, 14, 16, 38),
#  datetime.datetime(2017, 4, 14, 16, 39),
#  datetime.datetime(2017, 4, 14, 16, 40),
#  datetime.datetime(2017, 4, 14, 16, 41),
#  datetime.datetime(2017, 4, 14, 16, 42),
#  datetime.datetime(2017, 4, 14, 16, 43),
#  datetime.datetime(2017, 4, 14, 16, 44),
#  datetime.datetime(2017, 4, 14, 16, 45),
#  datetime.datetime(2017, 4, 14, 16, 46),
#  datetime.datetime(2017, 4, 14, 16, 47),
#  datetime.datetime(2017, 4, 14, 16, 48),
#  datetime.datetime(2017, 4, 14, 16, 49),
#  datetime.datetime(2017, 4, 14, 16, 50),
#  datetime.datetime(2017, 4, 14, 16, 51),
#  datetime.datetime(2017, 4, 14, 16, 52),
#  datetime.datetime(2017, 4, 14, 16, 53),
#  datetime.datetime(2017, 4, 14, 16, 54),
#  datetime.datetime(2017, 4, 14, 16, 55),
#  datetime.datetime(2017, 4, 14, 16, 56),
#  datetime.datetime(2017, 4, 14, 16, 57),
#  datetime.datetime(2017, 4, 14, 16, 58),
#  datetime.datetime(2017, 4, 14, 16, 59),
#  datetime.datetime(2017, 4, 14, 17, 0),
#  datetime.datetime(2017, 4, 14, 17, 1),
#  datetime.datetime(2017, 4, 14, 17, 2),
#  datetime.datetime(2017, 4, 14, 17, 3),
#  datetime.datetime(2017, 4, 14, 17, 4),
#  datetime.datetime(2017, 4, 14, 17, 5),
#  datetime.datetime(2017, 4, 14, 17, 6),
#  datetime.datetime(2017, 4, 14, 17, 7),
#  datetime.datetime(2017, 4, 14, 17, 8),
#  datetime.datetime(2017, 4, 14, 17, 9),
#  datetime.datetime(2017, 4, 14, 17, 10),
#  datetime.datetime(2017, 4, 14, 17, 11),
#  datetime.datetime(2017, 4, 14, 17, 12),
#  datetime.datetime(2017, 4, 14, 17, 13),
#  datetime.datetime(2017, 4, 14, 17, 14),
#  datetime.datetime(2017, 4, 14, 17, 15),
#  datetime.datetime(2017, 4, 14, 17, 16),
#  datetime.datetime(2017, 4, 14, 17, 17),
#  datetime.datetime(2017, 4, 14, 17, 18),
#  datetime.datetime(2017, 4, 14, 17, 19),
#  datetime.datetime(2017, 4, 14, 17, 20),
#  datetime.datetime(2017, 4, 14, 17, 21),
#  datetime.datetime(2017, 4, 14, 17, 22),
#  datetime.datetime(2017, 4, 14, 17, 23),
#  datetime.datetime(2017, 4, 14, 17, 24),
#  datetime.datetime(2017, 4, 14, 17, 25),
#  datetime.datetime(2017, 4, 14, 17, 26),
#  datetime.datetime(2017, 4, 14, 17, 27),
#  datetime.datetime(2017, 4, 14, 17, 28),
#  datetime.datetime(2017, 4, 14, 17, 29),
#  datetime.datetime(2017, 4, 14, 17, 30),
#  datetime.datetime(2017, 4, 14, 17, 31),
#  datetime.datetime(2017, 4, 14, 17, 32),
#  datetime.datetime(2017, 4, 14, 17, 33),
#  datetime.datetime(2017, 4, 14, 17, 34),
#  datetime.datetime(2017, 4, 14, 17, 35),
#  datetime.datetime(2017, 4, 14, 17, 36),
#  datetime.datetime(2017, 4, 14, 17, 37),
#  datetime.datetime(2017, 4, 14, 17, 38),
#  datetime.datetime(2017, 4, 14, 17, 39),
#  datetime.datetime(2017, 4, 14, 17, 40),
#  datetime.datetime(2017, 4, 14, 17, 41),
#  datetime.datetime(2017, 4, 14, 17, 42),
#  datetime.datetime(2017, 4, 14, 17, 43),
#  datetime.datetime(2017, 4, 14, 17, 44),
#  datetime.datetime(2017, 4, 14, 17, 45),
#  datetime.datetime(2017, 4, 14, 17, 46),
#  datetime.datetime(2017, 4, 14, 17, 47),
#  datetime.datetime(2017, 4, 14, 17, 48),
#  datetime.datetime(2017, 4, 14, 17, 49),
#  datetime.datetime(2017, 4, 14, 17, 50),
#  datetime.datetime(2017, 4, 14, 17, 51),
#  datetime.datetime(2017, 4, 14, 17, 52),
#  datetime.datetime(2017, 4, 14, 17, 53),
#  datetime.datetime(2017, 4, 14, 17, 54),
#  datetime.datetime(2017, 4, 14, 17, 55),
#  datetime.datetime(2017, 4, 14, 17, 56),
#  datetime.datetime(2017, 4, 14, 17, 57),
#  datetime.datetime(2017, 4, 14, 17, 58),
#  datetime.datetime(2017, 4, 14, 17, 59),
#  datetime.datetime(2017, 4, 14, 18, 0),
#  datetime.datetime(2017, 4, 14, 18, 1),
#  datetime.datetime(2017, 4, 14, 18, 2),
#  datetime.datetime(2017, 4, 14, 18, 3),
#  datetime.datetime(2017, 4, 14, 18, 4),
#  datetime.datetime(2017, 4, 14, 18, 5),
#  datetime.datetime(2017, 4, 14, 18, 6),
#  datetime.datetime(2017, 4, 14, 18, 7),
#  datetime.datetime(2017, 4, 14, 18, 8),
#  datetime.datetime(2017, 4, 14, 18, 9),
#  datetime.datetime(2017, 4, 14, 18, 10),
#  datetime.datetime(2017, 4, 14, 18, 11),
#  datetime.datetime(2017, 4, 14, 18, 12),
#  datetime.datetime(2017, 4, 14, 18, 13),
#  datetime.datetime(2017, 4, 14, 18, 14),
#  datetime.datetime(2017, 4, 14, 18, 15),
#  datetime.datetime(2017, 4, 14, 18, 16),
#  datetime.datetime(2017, 4, 14, 18, 17),
#  datetime.datetime(2017, 4, 14, 18, 18),
#  datetime.datetime(2017, 4, 14, 18, 19),
#  datetime.datetime(2017, 4, 14, 18, 20),
#  datetime.datetime(2017, 4, 14, 18, 21),
#  datetime.datetime(2017, 4, 14, 18, 22),
#  datetime.datetime(2017, 4, 14, 18, 23),
#  datetime.datetime(2017, 4, 14, 18, 24),
#  datetime.datetime(2017, 4, 14, 18, 25),
#  datetime.datetime(2017, 4, 14, 18, 26),
#  datetime.datetime(2017, 4, 14, 18, 27),
#  datetime.datetime(2017, 4, 14, 18, 28),
#  datetime.datetime(2017, 4, 14, 18, 29),
#  datetime.datetime(2017, 4, 14, 18, 30),
#  datetime.datetime(2017, 4, 14, 18, 31),
#  datetime.datetime(2017, 4, 14, 18, 32),
#  datetime.datetime(2017, 4, 14, 18, 33),
#  datetime.datetime(2017, 4, 14, 18, 34),
#  datetime.datetime(2017, 4, 14, 18, 35),
#  datetime.datetime(2017, 4, 14, 18, 36),
#  datetime.datetime(2017, 4, 14, 18, 37),
#  datetime.datetime(2017, 4, 14, 18, 38),
#  datetime.datetime(2017, 4, 14, 18, 39),
#  datetime.datetime(2017, 4, 14, 18, 40),
#  datetime.datetime(2017, 4, 14, 18, 41),
#  datetime.datetime(2017, 4, 14, 18, 42),
#  datetime.datetime(2017, 4, 14, 18, 43),
#  datetime.datetime(2017, 4, 14, 18, 44),
#  datetime.datetime(2017, 4, 14, 18, 45),
#  datetime.datetime(2017, 4, 14, 18, 46),
#  datetime.datetime(2017, 4, 14, 18, 47),
#  datetime.datetime(2017, 4, 14, 18, 48),
#  datetime.datetime(2017, 4, 14, 18, 49),
#  datetime.datetime(2017, 4, 14, 18, 50),
#  datetime.datetime(2017, 4, 14, 18, 51),
#  datetime.datetime(2017, 4, 14, 18, 52),
#  datetime.datetime(2017, 4, 14, 18, 53),
#  datetime.datetime(2017, 4, 14, 18, 54),
#  datetime.datetime(2017, 4, 14, 18, 55),
#  datetime.datetime(2017, 4, 14, 18, 56),
#  datetime.datetime(2017, 4, 14, 18, 57),
#  datetime.datetime(2017, 4, 14, 18, 58),
#  datetime.datetime(2017, 4, 14, 18, 59),
#  datetime.datetime(2017, 4, 14, 19, 0),
#  datetime.datetime(2017, 4, 14, 19, 1),
#  datetime.datetime(2017, 4, 14, 19, 2),
#  datetime.datetime(2017, 4, 14, 19, 3),
#  datetime.datetime(2017, 4, 14, 19, 4),
#  datetime.datetime(2017, 4, 14, 19, 5),
#  datetime.datetime(2017, 4, 14, 19, 6),
#  datetime.datetime(2017, 4, 14, 19, 7),
#  datetime.datetime(2017, 4, 14, 19, 8),
#  datetime.datetime(2017, 4, 14, 19, 9),
#  datetime.datetime(2017, 4, 14, 19, 10),
#  datetime.datetime(2017, 4, 14, 19, 11),
#  datetime.datetime(2017, 4, 14, 19, 12),
#  datetime.datetime(2017, 4, 14, 19, 13),
#  datetime.datetime(2017, 4, 14, 19, 14),
#  datetime.datetime(2017, 4, 14, 19, 15),
#  datetime.datetime(2017, 4, 14, 19, 16),
#  datetime.datetime(2017, 4, 14, 19, 17),
#  datetime.datetime(2017, 4, 14, 19, 18),
#  datetime.datetime(2017, 4, 14, 19, 19),
#  datetime.datetime(2017, 4, 14, 19, 20),
#  datetime.datetime(2017, 4, 14, 19, 21),
#  datetime.datetime(2017, 4, 14, 19, 22),
#  datetime.datetime(2017, 4, 14, 19, 23),
#  datetime.datetime(2017, 4, 14, 19, 24),
#  datetime.datetime(2017, 4, 14, 19, 25),
#  datetime.datetime(2017, 4, 14, 19, 26),
#  datetime.datetime(2017, 4, 14, 19, 27),
#  datetime.datetime(2017, 4, 14, 19, 28),
#  datetime.datetime(2017, 4, 14, 19, 29),
#  datetime.datetime(2017, 4, 14, 19, 30),
#  datetime.datetime(2017, 4, 14, 19, 31),
#  datetime.datetime(2017, 4, 14, 19, 32),
#  datetime.datetime(2017, 4, 14, 19, 33),
#  datetime.datetime(2017, 4, 14, 19, 34),
#  datetime.datetime(2017, 4, 14, 19, 35),
#  datetime.datetime(2017, 4, 14, 19, 36),
#  datetime.datetime(2017, 4, 14, 19, 37),
#  datetime.datetime(2017, 4, 14, 19, 38),
#  datetime.datetime(2017, 4, 14, 19, 39),
#  datetime.datetime(2017, 4, 14, 19, 40),
#  datetime.datetime(2017, 4, 14, 19, 41),
#  datetime.datetime(2017, 4, 14, 19, 42),
#  datetime.datetime(2017, 4, 14, 19, 43),
#  datetime.datetime(2017, 4, 14, 19, 44),
#  datetime.datetime(2017, 4, 14, 19, 45),
#  datetime.datetime(2017, 4, 14, 19, 46),
#  datetime.datetime(2017, 4, 14, 19, 47),
#  datetime.datetime(2017, 4, 14, 19, 48),
#  datetime.datetime(2017, 4, 14, 19, 49),
#  datetime.datetime(2017, 4, 14, 19, 50),
#  datetime.datetime(2017, 4, 14, 19, 51),
#  datetime.datetime(2017, 4, 14, 19, 52),
#  datetime.datetime(2017, 4, 14, 19, 53),
#  datetime.datetime(2017, 4, 14, 19, 54),
#  datetime.datetime(2017, 4, 14, 19, 55),
#  datetime.datetime(2017, 4, 14, 19, 56),
#  datetime.datetime(2017, 4, 14, 19, 57),
#  datetime.datetime(2017, 4, 14, 19, 58),
#  datetime.datetime(2017, 4, 14, 19, 59),
#  datetime.datetime(2017, 4, 14, 20, 0),
#  datetime.datetime(2017, 4, 14, 20, 1),
#  datetime.datetime(2017, 4, 14, 20, 2),
#  datetime.datetime(2017, 4, 14, 20, 3),
#  datetime.datetime(2017, 4, 14, 20, 4),
#  datetime.datetime(2017, 4, 14, 20, 5),
#  datetime.datetime(2017, 4, 14, 20, 6),
#  datetime.datetime(2017, 4, 14, 20, 7),
#  datetime.datetime(2017, 4, 14, 20, 8),
#  datetime.datetime(2017, 4, 14, 20, 9),
#  datetime.datetime(2017, 4, 14, 20, 10),
#  datetime.datetime(2017, 4, 14, 20, 11),
#  datetime.datetime(2017, 4, 14, 20, 12),
#  datetime.datetime(2017, 4, 14, 20, 13),
#  datetime.datetime(2017, 4, 14, 20, 14),
#  datetime.datetime(2017, 4, 14, 20, 15),
#  datetime.datetime(2017, 4, 14, 20, 16),
#  datetime.datetime(2017, 4, 14, 20, 17),
#  datetime.datetime(2017, 4, 14, 20, 18),
#  datetime.datetime(2017, 4, 14, 20, 19),
#  datetime.datetime(2017, 4, 14, 20, 20),
#  datetime.datetime(2017, 4, 14, 20, 21),
#  datetime.datetime(2017, 4, 14, 20, 22),
#  datetime.datetime(2017, 4, 14, 20, 23),
#  datetime.datetime(2017, 4, 14, 20, 24),
#  datetime.datetime(2017, 4, 14, 20, 25),
#  datetime.datetime(2017, 4, 14, 20, 26),
#  datetime.datetime(2017, 4, 14, 20, 27),
#  datetime.datetime(2017, 4, 14, 20, 28),
#  datetime.datetime(2017, 4, 14, 20, 29),
#  datetime.datetime(2017, 4, 14, 20, 30),
#  datetime.datetime(2017, 4, 14, 20, 31),
#  datetime.datetime(2017, 4, 14, 20, 32),
#  datetime.datetime(2017, 4, 14, 20, 33),
#  datetime.datetime(2017, 4, 14, 20, 34),
#  datetime.datetime(2017, 4, 14, 20, 35),
#  datetime.datetime(2017, 4, 14, 20, 36),
#  datetime.datetime(2017, 4, 14, 20, 37),
#  datetime.datetime(2017, 4, 14, 20, 38),
#  datetime.datetime(2017, 4, 14, 20, 39),
#  datetime.datetime(2017, 4, 14, 20, 40),
#  datetime.datetime(2017, 4, 14, 20, 41),
#  datetime.datetime(2017, 4, 14, 20, 42),
#  datetime.datetime(2017, 4, 14, 20, 43),
#  datetime.datetime(2017, 4, 14, 20, 44),
#  datetime.datetime(2017, 4, 14, 20, 45),
#  datetime.datetime(2017, 4, 14, 20, 46),
#  datetime.datetime(2017, 4, 14, 20, 47),
#  datetime.datetime(2017, 4, 14, 20, 48),
#  datetime.datetime(2017, 4, 14, 20, 49),
#  datetime.datetime(2017, 4, 14, 20, 50),
#  datetime.datetime(2017, 4, 14, 20, 51),
#  datetime.datetime(2017, 4, 14, 20, 52),
#  datetime.datetime(2017, 4, 14, 20, 53),
#  datetime.datetime(2017, 4, 14, 20, 54),
#  datetime.datetime(2017, 4, 14, 20, 55),
#  datetime.datetime(2017, 4, 14, 20, 56),
#  datetime.datetime(2017, 4, 14, 20, 57),
#  datetime.datetime(2017, 4, 14, 20, 58),
#  datetime.datetime(2017, 4, 14, 20, 59),
#  datetime.datetime(2017, 4, 14, 21, 0),
#  datetime.datetime(2017, 4, 14, 21, 1),
#  datetime.datetime(2017, 4, 14, 21, 2),
#  datetime.datetime(2017, 4, 14, 21, 3),
#  datetime.datetime(2017, 4, 14, 21, 4),
#  datetime.datetime(2017, 4, 14, 21, 5),
#  datetime.datetime(2017, 4, 14, 21, 6),
#  datetime.datetime(2017, 4, 14, 21, 7),
#  datetime.datetime(2017, 4, 14, 21, 8),
#  datetime.datetime(2017, 4, 14, 21, 9),
#  datetime.datetime(2017, 4, 14, 21, 10),
#  datetime.datetime(2017, 4, 14, 21, 11),
#  datetime.datetime(2017, 4, 14, 21, 12),
#  datetime.datetime(2017, 4, 14, 21, 13),
#  datetime.datetime(2017, 4, 14, 21, 14),
#  datetime.datetime(2017, 4, 14, 21, 15),
#  datetime.datetime(2017, 4, 14, 21, 16),
#  datetime.datetime(2017, 4, 14, 21, 17),
#  datetime.datetime(2017, 4, 14, 21, 18),
#  datetime.datetime(2017, 4, 14, 21, 19),
#  datetime.datetime(2017, 4, 14, 21, 20),
#  datetime.datetime(2017, 4, 14, 21, 21),
#  datetime.datetime(2017, 4, 14, 21, 22),
#  datetime.datetime(2017, 4, 14, 21, 23),
#  datetime.datetime(2017, 4, 14, 21, 24),
#  datetime.datetime(2017, 4, 14, 21, 25),
#  datetime.datetime(2017, 4, 14, 21, 26),
#  datetime.datetime(2017, 4, 14, 21, 27),
#  datetime.datetime(2017, 4, 14, 21, 28),
#  datetime.datetime(2017, 4, 14, 21, 29),
#  datetime.datetime(2017, 4, 14, 21, 30),
#  datetime.datetime(2017, 4, 14, 21, 31),
#  datetime.datetime(2017, 4, 14, 21, 32),
#  datetime.datetime(2017, 4, 14, 21, 33),
#  datetime.datetime(2017, 4, 14, 21, 34),
#  datetime.datetime(2017, 4, 14, 21, 35),
#  datetime.datetime(2017, 4, 14, 21, 36),
#  datetime.datetime(2017, 4, 14, 21, 37),
#  datetime.datetime(2017, 4, 14, 21, 38),
#  datetime.datetime(2017, 4, 14, 21, 39),
#  datetime.datetime(2017, 4, 14, 21, 40),
#  datetime.datetime(2017, 4, 14, 21, 41),
#  datetime.datetime(2017, 4, 14, 21, 42),
#  datetime.datetime(2017, 4, 14, 21, 43),
#  datetime.datetime(2017, 4, 14, 21, 44),
#  datetime.datetime(2017, 4, 14, 21, 45),
#  datetime.datetime(2017, 4, 14, 21, 46),
#  datetime.datetime(2017, 4, 14, 21, 47),
#  datetime.datetime(2017, 4, 14, 21, 48),
#  datetime.datetime(2017, 4, 14, 21, 49),
#  datetime.datetime(2017, 4, 14, 21, 50),
#  datetime.datetime(2017, 4, 14, 21, 51),
#  datetime.datetime(2017, 4, 14, 21, 52),
#  datetime.datetime(2017, 4, 14, 21, 53),
#  datetime.datetime(2017, 4, 14, 21, 54),
#  datetime.datetime(2017, 4, 14, 21, 55),
#  datetime.datetime(2017, 4, 14, 21, 56),
#  datetime.datetime(2017, 4, 14, 21, 57),
#  datetime.datetime(2017, 4, 14, 21, 58),
#  datetime.datetime(2017, 4, 14, 21, 59),
#  datetime.datetime(2017, 4, 14, 22, 0),
#  datetime.datetime(2017, 4, 14, 22, 1),
#  datetime.datetime(2017, 4, 14, 22, 2),
#  datetime.datetime(2017, 4, 14, 22, 3),
#  datetime.datetime(2017, 4, 14, 22, 4),
#  datetime.datetime(2017, 4, 14, 22, 5),
#  datetime.datetime(2017, 4, 14, 22, 6),
#  datetime.datetime(2017, 4, 14, 22, 7),
#  datetime.datetime(2017, 4, 14, 22, 8),
#  datetime.datetime(2017, 4, 14, 22, 9),
#  datetime.datetime(2017, 4, 14, 22, 10),
#  datetime.datetime(2017, 4, 14, 22, 11),
#  datetime.datetime(2017, 4, 14, 22, 12),
#  datetime.datetime(2017, 4, 14, 22, 13),
#  datetime.datetime(2017, 4, 14, 22, 14),
#  datetime.datetime(2017, 4, 14, 22, 15),
#  datetime.datetime(2017, 4, 14, 22, 16),
#  datetime.datetime(2017, 4, 14, 22, 17),
#  datetime.datetime(2017, 4, 14, 22, 18),
#  datetime.datetime(2017, 4, 14, 22, 19),
#  datetime.datetime(2017, 4, 14, 22, 20),
#  datetime.datetime(2017, 4, 14, 22, 21),
#  datetime.datetime(2017, 4, 14, 22, 22),
#  datetime.datetime(2017, 4, 14, 22, 23),
#  datetime.datetime(2017, 4, 14, 22, 24),
#  datetime.datetime(2017, 4, 14, 22, 25),
#  datetime.datetime(2017, 4, 14, 22, 26),
#  datetime.datetime(2017, 4, 14, 22, 27),
#  datetime.datetime(2017, 4, 14, 22, 28),
#  datetime.datetime(2017, 4, 14, 22, 29),
#  datetime.datetime(2017, 4, 14, 22, 30),
#  datetime.datetime(2017, 4, 14, 22, 31),
#  datetime.datetime(2017, 4, 14, 22, 32),
#  datetime.datetime(2017, 4, 14, 22, 33),
#  datetime.datetime(2017, 4, 14, 22, 34),
#  datetime.datetime(2017, 4, 14, 22, 35),
#  datetime.datetime(2017, 4, 14, 22, 36),
#  datetime.datetime(2017, 4, 14, 22, 37),
#  datetime.datetime(2017, 4, 14, 22, 38),
#  datetime.datetime(2017, 4, 14, 22, 39),
#  datetime.datetime(2017, 4, 14, 22, 40),
#  datetime.datetime(2017, 4, 14, 22, 41),
#  datetime.datetime(2017, 4, 14, 22, 42),
#  datetime.datetime(2017, 4, 14, 22, 43),
#  datetime.datetime(2017, 4, 14, 22, 44),
#  datetime.datetime(2017, 4, 14, 22, 45),
#  datetime.datetime(2017, 4, 14, 22, 46),
#  datetime.datetime(2017, 4, 14, 22, 47),
#  datetime.datetime(2017, 4, 14, 22, 48),
#  datetime.datetime(2017, 4, 14, 22, 49),
#  datetime.datetime(2017, 4, 14, 22, 50),
#  datetime.datetime(2017, 4, 14, 22, 51),
#  datetime.datetime(2017, 4, 14, 22, 52),
#  datetime.datetime(2017, 4, 14, 22, 53),
#  datetime.datetime(2017, 4, 14, 22, 54),
#  datetime.datetime(2017, 4, 14, 22, 55),
#  datetime.datetime(2017, 4, 14, 22, 56),
#  datetime.datetime(2017, 4, 14, 22, 57),
#  datetime.datetime(2017, 4, 14, 22, 58),
#  datetime.datetime(2017, 4, 14, 22, 59),
#  datetime.datetime(2017, 4, 14, 23, 0),
#  datetime.datetime(2017, 4, 14, 23, 1),
#  datetime.datetime(2017, 4, 14, 23, 2),
#  datetime.datetime(2017, 4, 14, 23, 3),
#  datetime.datetime(2017, 4, 14, 23, 4),
#  datetime.datetime(2017, 4, 14, 23, 5),
#  datetime.datetime(2017, 4, 14, 23, 6),
#  datetime.datetime(2017, 4, 14, 23, 7),
#  datetime.datetime(2017, 4, 14, 23, 8),
#  datetime.datetime(2017, 4, 14, 23, 9),
#  datetime.datetime(2017, 4, 14, 23, 10),
#  datetime.datetime(2017, 4, 14, 23, 11),
#  datetime.datetime(2017, 4, 14, 23, 12),
#  datetime.datetime(2017, 4, 14, 23, 13),
#  datetime.datetime(2017, 4, 14, 23, 14),
#  datetime.datetime(2017, 4, 14, 23, 15),
#  datetime.datetime(2017, 4, 14, 23, 16),
#  datetime.datetime(2017, 4, 14, 23, 17),
#  datetime.datetime(2017, 4, 14, 23, 18),
#  datetime.datetime(2017, 4, 14, 23, 19),
#  datetime.datetime(2017, 4, 14, 23, 20),
#  datetime.datetime(2017, 4, 14, 23, 21),
#  datetime.datetime(2017, 4, 14, 23, 22),
#  datetime.datetime(2017, 4, 14, 23, 23),
#  datetime.datetime(2017, 4, 14, 23, 24),
#  datetime.datetime(2017, 4, 14, 23, 25),
#  datetime.datetime(2017, 4, 14, 23, 26),
#  datetime.datetime(2017, 4, 14, 23, 27),
#  datetime.datetime(2017, 4, 14, 23, 28),
#  datetime.datetime(2017, 4, 14, 23, 29),
#  datetime.datetime(2017, 4, 14, 23, 30),
#  datetime.datetime(2017, 4, 14, 23, 31),
#  datetime.datetime(2017, 4, 14, 23, 32),
#  datetime.datetime(2017, 4, 14, 23, 33),
#  datetime.datetime(2017, 4, 14, 23, 34),
#  datetime.datetime(2017, 4, 14, 23, 35),
#  datetime.datetime(2017, 4, 14, 23, 36),
#  datetime.datetime(2017, 4, 14, 23, 37),
#  datetime.datetime(2017, 4, 14, 23, 38),
#  datetime.datetime(2017, 4, 14, 23, 39),
#  datetime.datetime(2017, 4, 14, 23, 40),
#  datetime.datetime(2017, 4, 14, 23, 41),
#  datetime.datetime(2017, 4, 14, 23, 42),
#  datetime.datetime(2017, 4, 14, 23, 43),
#  datetime.datetime(2017, 4, 14, 23, 44),
#  datetime.datetime(2017, 4, 14, 23, 45),
#  datetime.datetime(2017, 4, 14, 23, 46),
#  datetime.datetime(2017, 4, 14, 23, 47),
#  datetime.datetime(2017, 4, 14, 23, 48),
#  datetime.datetime(2017, 4, 14, 23, 49),
#  datetime.datetime(2017, 4, 14, 23, 50),
#  datetime.datetime(2017, 4, 14, 23, 51),
#  datetime.datetime(2017, 4, 14, 23, 52),
#  datetime.datetime(2017, 4, 14, 23, 53),
#  datetime.datetime(2017, 4, 14, 23, 54),
#  datetime.datetime(2017, 4, 14, 23, 55),
#  datetime.datetime(2017, 4, 14, 23, 56),
#  datetime.datetime(2017, 4, 14, 23, 57),
#  datetime.datetime(2017, 4, 14, 23, 58),
#  datetime.datetime(2017, 4, 14, 23, 59),
#  datetime.datetime(2017, 4, 15, 0, 0),
#  datetime.datetime(2017, 4, 15, 0, 1),
#  datetime.datetime(2017, 4, 15, 0, 2),
#  datetime.datetime(2017, 4, 15, 0, 3),
#  datetime.datetime(2017, 4, 15, 0, 4),
#  datetime.datetime(2017, 4, 15, 0, 5),
#  datetime.datetime(2017, 4, 15, 0, 6),
#  datetime.datetime(2017, 4, 15, 0, 7),
#  datetime.datetime(2017, 4, 15, 0, 8),
#  datetime.datetime(2017, 4, 15, 0, 9),
#  datetime.datetime(2017, 4, 15, 0, 10),
#  datetime.datetime(2017, 4, 15, 0, 11),
#  datetime.datetime(2017, 4, 15, 0, 12),
#  datetime.datetime(2017, 4, 15, 0, 13),
#  datetime.datetime(2017, 4, 15, 0, 14),
#  datetime.datetime(2017, 4, 15, 0, 15),
#  datetime.datetime(2017, 4, 15, 0, 16),
#  datetime.datetime(2017, 4, 15, 0, 17),
#  datetime.datetime(2017, 4, 15, 0, 18),
#  datetime.datetime(2017, 4, 15, 0, 19),
#  datetime.datetime(2017, 4, 15, 0, 20),
#  datetime.datetime(2017, 4, 15, 0, 21),
#  datetime.datetime(2017, 4, 15, 0, 22),
#  datetime.datetime(2017, 4, 15, 0, 23),
#  datetime.datetime(2017, 4, 15, 0, 24),
#  datetime.datetime(2017, 4, 15, 0, 25),
#  datetime.datetime(2017, 4, 15, 0, 26),
#  datetime.datetime(2017, 4, 15, 0, 27),
#  datetime.datetime(2017, 4, 15, 0, 28),
#  datetime.datetime(2017, 4, 15, 0, 29),
#  datetime.datetime(2017, 4, 15, 0, 30),
#  datetime.datetime(2017, 4, 15, 0, 31),
#  datetime.datetime(2017, 4, 15, 0, 32),
#  datetime.datetime(2017, 4, 15, 0, 33),
#  datetime.datetime(2017, 4, 15, 0, 34),
#  datetime.datetime(2017, 4, 15, 0, 35),
#  datetime.datetime(2017, 4, 15, 0, 36),
#  datetime.datetime(2017, 4, 15, 0, 37),
#  datetime.datetime(2017, 4, 15, 0, 38),
#  datetime.datetime(2017, 4, 15, 0, 39),
#  datetime.datetime(2017, 4, 15, 0, 40),
#  datetime.datetime(2017, 4, 15, 0, 41),
#  datetime.datetime(2017, 4, 15, 0, 42),
#  datetime.datetime(2017, 4, 15, 0, 43),
#  datetime.datetime(2017, 4, 15, 0, 44),
#  datetime.datetime(2017, 4, 15, 0, 45),
#  ...]

# %% [markdown]
# # SelectKBest Variable selection
# ['R1_RDT_Total_Feed' 'R2_RDT_T_PAR' 'R2_RDT_Total_Feed' 'R2_RDT_PAR_FEED'
#  'R3_RDT_Total_Feed' 'R3_RDT_PAR_FEED' 'R3_RDT_T_PAR' 'R4_RDT_T_ARO'
#  'R4_RDT_T_PAR' 'R4_RDT_PAR_FEED' 'R2_RIT_mean' 'R2_RIT_max'
#  'Re_Gas_H2_purity' 'C_1_DISCH' 'Re_Gas_MOLAR_RATIO' 'C_1_SUCTION'
#  'Catalyst_V3_front_coke Content' 'V-3 1ST BURN ZON E-1 INLET GAS'
#  'V-3 1ST BURN ZON H-1 OUTLET' 'Burning Gas C-2 OUT TO V-3'
#  'R-3 OUT H-4 IN (R-3 ROT)']

# %%
fig = plt.figure(figsize=(8,6), dpi=80)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
fig.autofmt_xdate()

# Add axis labels
plt.xlabel('time')
plt.ylabel('2nd.bz.max.temp')
plt.title('prediction vs original')

plt.plot(strtodate(test_date), prediction, color="red", linestyle="-",
        linewidth=0.5)
plt.plot(strtodate(test_date), real, color="blue", linestyle="-",
        linewidth=0.5)
plt.show()
#fig.savefig(join(data_dir,title + '.pdf'))

# %%
scaled_train_df.columns.values[0]
# Out:
# 'R1_RDT_Total_Feed'

# %% [markdown]
# # RFECV Variable selection

# %% [markdown]
# [R1_RDT_Total_Feed' 'R1_RDT_T_PAR' 'R2_RDT_Total_Feed' 'R3_RDT_Total_Feed'
#  'R3_RDT_T_ARO' 'R4_RDT_T_ARO' 'R4_RDT_Total_Feed' 'Re_Gas_H2_purity'
#  'R4_New_Wait' 'V-3 1ST BURN ZON E-1 INLET GAS'
#  'V-3 1ST BURN ZON H-1 OUTLET' 'Burning Gas C-2 OUT TO V-3'
#  'ATMOSPHERE Burning Gas TEMP']

# %%
with open(r'C:\Users\Administrator\Desktop\KYJ\coke\real_rfecv.pkl', 'rb') as fid:
    rfecv = cPickle.load(fid)

# %%
with open(r'C:\Users\Administrator\Desktop\KYJ\coke\prediction.pkl', 'rb') as fid:
    rfe_prediction = cPickle.load(fid)

# %%
fig = plt.figure(figsize=(8,6), dpi=80)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
fig.autofmt_xdate()

# Add axis labels
plt.xlabel('time')
plt.ylabel('2nd.bz.max.temp')
plt.title('prediction vs original')

plt.plot(strtodate(test_date), rfe_prediction, color="red", linestyle="-",
        linewidth=0.5)
plt.plot(strtodate(test_date), real, color="blue", linestyle="-",
        linewidth=0.5)
plt.show()
#fig.savefig(join(data_dir,title + '.pdf'))
